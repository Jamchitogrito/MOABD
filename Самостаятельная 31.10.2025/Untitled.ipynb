# %%
import sys
print(sys.executable)
# !pip show folium
# Out:
# C:\Users\dinislam\Documents\Practick\MO&BD\Самостаятельная 31.10.2025\.venv\Scripts\python.exe
# Name: folium
# Version: 0.20.0
# Summary: Make beautiful maps with Leaflet.js & Python
# Home-page: https://github.com/python-visualization/folium
# Author: Rob Story
# Author-email: wrobstory@gmail.com
# License: MIT
# Location: C:\Users\dinislam\Documents\Practick\MO&BD\Самостаятельная 31.10.2025\.venv\Lib\site-packages
# Requires: branca, jinja2, numpy, requests, xyzservices
# Required-by:

# %%
import folium as fm
print(folium.__version__)  # Должен вывести 0.20.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import folium as fm
# ----> 2 print(folium.__version__)  # Должен вывести 0.20.0
#
# NameError: name 'folium' is not defined

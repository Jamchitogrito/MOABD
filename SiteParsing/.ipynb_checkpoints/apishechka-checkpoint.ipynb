# %% [markdown]
# # Импорт модулей

# %%
import pandas as pd

# %%
import requests

# %%
import json

# %%
from datetime import datetime

# %%
API_KEY = "QTDWSSW-P59M41D-K4HPD21-4YSPWW2"

# %%
BASE_URL = "https://api.poiskkino.dev"

# %%
headers = {
    "X-API-KEY": API_KEY,
    "accept": "application/json"
}

# %%
def get_movies(params=None):
    """
    page - страница
    limit - количество
    year - год/диапазон
    raiting.kp - рейтинг
    genres.name - жанр
    """
    url = f"{BASE_URL}/v1.4/movie"
    response = requests.get(url, headers=headers, params=params)
    if (response.status_code == 200):
        return response.json
    else:
        print(f"Ошибка при получении данных {response.status_code}")
        return None

# %% [markdown]
# # Работа с апи

# %%
params = {
    "page": 1,
    "limit": 250,
    "notNullFields": [
        "description",
        "name",
        "year", 
        "rating.kp",
        "genres.name"
    ]
}

# %%
data = get_movies(params)

# %%
df = pd.DataFrame(data()['docs'])

# %%
df.head()
# Out:
#          id  ageRating                           alternativeName  \
# 0  11887825       18.0  О чём на самом деле «Марти Великолепный»
# 1  12174541        NaN                    Meurtres aux Marquises
# 2  12095806        6.0                        Космические котята
# 3  11921442       18.0                            Snowball Earth
# 4  11940727       18.0            Kami no Niwatsuki Kusunoki-tei
#
#                                             backdrop  \
# 0  {'url': 'https://avatars.mds.yandex.net/get-ot...
# 1  {'previewUrl': 'https://avatars.mds.yandex.net...
# 2  {'url': 'https://avatars.mds.yandex.net/get-ot...
# 3  {'url': 'https://avatars.mds.yandex.net/get-ot...
# 4  {'url': 'https://avatars.mds.yandex.net/get-ot...
#
#                                     countries  \
# 0                        [{'name': 'Россия'}]
# 1  [{'name': 'Франция'}, {'name': 'Бельгия'}]
# 2                        [{'name': 'Россия'}]
# 3                        [{'name': 'Япония'}]
# 4                        [{'name': 'Япония'}]
#
#                                          description  \
# 0  Редакция Кинопоиска разбирается, как устроена ...
# 1  Тяжело переживая трагедию, из‑за которой ей пр...
# 2  В жизни Дениса Кукояки хватало съемок, приключ...
# 3  На Землю нападают пришельцы из космоса. Просто...
# 4  Семья поручила Минато Кусуноки присматривать з...
#
#                                               genres  isSeries  movieLength  \
# 0  [{'name': 'короткометражка'}, {'name': 'докуме...     False         10.0
# 1       [{'name': 'детектив'}, {'name': 'криминал'}]     False         94.0
# 2  [{'name': 'документальный'}, {'name': 'коротко...     False         28.0
# 3  [{'name': 'аниме'}, {'name': 'мультфильм'}, {'...      True          NaN
# 4  [{'name': 'аниме'}, {'name': 'мультфильм'}, {'...      True          NaN
#
#                                        name  ... typeNumber  \
# 0  О чём на самом деле «Марти Великолепный»  ...          1
# 1           Убийство на Маркизских островах  ...          1
# 2                        Космические котята  ...          1
# 3                              Земля-снежок  ...          4
# 4      Божественный сад у поместья Кусуноки  ...          4
#
#                       votes  year  \
# 0              {'kp': 4561}  2026
# 1              {'imdb': 28}  2025
# 2              {'kp': 4553}  2026
# 3   {'kp': 272, 'imdb': 33}  2026
# 4  {'kp': 3727, 'imdb': 31}  2026
#
#                                                names       releaseYears  \
# 0  [{'name': 'О чём на самом деле «Марти Великоле...                NaN
# 1  [{'name': 'Убийство на Маркизских островах', '...                NaN
# 2  [{'name': 'Космические котята', 'language': 'R...                NaN
# 3  [{'name': 'Snowball Earth', 'language': None, ...  [{'start': 2026}]
# 4  [{'name': 'Kami no Niwatsuki Kusunoki-tei', 'l...  [{'start': 2026}]
#
#    seriesLength ratingMpaa  totalSeriesLength status logo
# 0           NaN        NaN                NaN    NaN  NaN
# 1           NaN        NaN                NaN    NaN  NaN
# 2           NaN        NaN                NaN    NaN  NaN
# 3          23.0        NaN                NaN    NaN  NaN
# 4          23.0        NaN                NaN    NaN  NaN
#
# [5 rows x 25 columns]

# %%
df_noorm = df[['name','year', 'description', 'countries']].copy()

# %%
df_noorm['countries'] = df['countries'].apply(lambda x: x[0]['name'] if isinstance(x, list) and len(x) > 0 else None)

# %%
df_noorm['rating'] = df['rating'].apply(lambda x: x.get('kp') if pd.notna(x) else None)

# %%
df_noorm['genres'] = df['genres'].apply(
    lambda x: ', '.join([g['name'] for g in x]) if isinstance(x, list) else ''
)

# %%
df_noorm.head(250)
# Out:
#                                          name  year  \
# 0    О чём на самом деле «Марти Великолепный»  2026
# 1             Убийство на Маркизских островах  2025
# 2                          Космические котята  2026
# 3                                Земля-снежок  2026
# 4        Божественный сад у поместья Кусуноки  2026
# ..                                        ...   ...
# 245                        Правда о прививках  2006
# 246                                      Град  2010
# 247                       Поединки: Вербовщик  2010
# 248                            Тигровые глаза  2012
# 249                    Дети кукурузы: Генезис  2011
#
#                                            description countries  rating  \
# 0    Редакция Кинопоиска разбирается, как устроена ...    Россия   7.668
# 1    Тяжело переживая трагедию, из‑за которой ей пр...   Франция   6.889
# 2    В жизни Дениса Кукояки хватало съемок, приключ...    Россия   7.382
# 3    На Землю нападают пришельцы из космоса. Просто...    Япония   7.573
# 4    Семья поручила Минато Кусуноки присматривать з...    Япония   8.490
# ..                                                 ...       ...     ...
# 245  Приводятся данные из документов для служебного...    Россия   6.258
# 246  Осадки бывают разные, но этот больнее всех бьё...    Россия   5.413
# 247  Даже на фоне других героев «невидимого фронта»...    Россия   7.082
# 248  После гибели отца в ходе ограбления Дэйви, ее ...       США   6.168
# 249  Сломав машину и застряв посреди калифорнийской...       США   3.254
#
#                                          genres
# 0               короткометражка, документальный
# 1                            детектив, криминал
# 2        документальный, короткометражка, спорт
# 3    аниме, мультфильм, фантастика, приключения
# 4    аниме, мультфильм, фэнтези, драма, комедия
# ..                                          ...
# 245                              документальный
# 246                            триллер, комедия
# 247              документальный, драма, история
# 248        драма, мелодрама, детектив, семейный
# 249                              ужасы, триллер
#
# [250 rows x 6 columns]

# %%
df_with_description = df_noorm[df_noorm['description'].notna() & (df_noorm['description'] != '')].copy()

# %%
df_with_description.head(250)
# Out:
#                                          name  year  \
# 0    О чём на самом деле «Марти Великолепный»  2026
# 1             Убийство на Маркизских островах  2025
# 2                          Космические котята  2026
# 3                                Земля-снежок  2026
# 4        Божественный сад у поместья Кусуноки  2026
# ..                                        ...   ...
# 245                        Правда о прививках  2006
# 246                                      Град  2010
# 247                       Поединки: Вербовщик  2010
# 248                            Тигровые глаза  2012
# 249                    Дети кукурузы: Генезис  2011
#
#                                            description countries  rating  \
# 0    Редакция Кинопоиска разбирается, как устроена ...    Россия   7.668
# 1    Тяжело переживая трагедию, из‑за которой ей пр...   Франция   6.889
# 2    В жизни Дениса Кукояки хватало съемок, приключ...    Россия   7.382
# 3    На Землю нападают пришельцы из космоса. Просто...    Япония   7.573
# 4    Семья поручила Минато Кусуноки присматривать з...    Япония   8.490
# ..                                                 ...       ...     ...
# 245  Приводятся данные из документов для служебного...    Россия   6.258
# 246  Осадки бывают разные, но этот больнее всех бьё...    Россия   5.413
# 247  Даже на фоне других героев «невидимого фронта»...    Россия   7.082
# 248  После гибели отца в ходе ограбления Дэйви, ее ...       США   6.168
# 249  Сломав машину и застряв посреди калифорнийской...       США   3.254
#
#                                          genres
# 0               короткометражка, документальный
# 1                            детектив, криминал
# 2        документальный, короткометражка, спорт
# 3    аниме, мультфильм, фантастика, приключения
# 4    аниме, мультфильм, фэнтези, драма, комедия
# ..                                          ...
# 245                              документальный
# 246                            триллер, комедия
# 247              документальный, драма, история
# 248        драма, мелодрама, детектив, семейный
# 249                              ужасы, триллер
#
# [250 rows x 6 columns]

# %%
print(len(df_noorm))
# Out:
# 250

# %%
print(len(df_with_description))
# Out:
# 250

# %% [markdown]
# # Экспорт в CSV

# %%
df_noorm.to_csv('films.csv', index=False)
